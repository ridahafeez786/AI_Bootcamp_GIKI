# %% [markdown]
# <a href="https://colab.research.google.com/github/ridahafeez786/AI_Bootcamp_Lab-work/blob/main/LLM_Reasoning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROMPT ENGINEERING
#
# Understanding
#
#
# *   Chain of Thought
# *   Self Consistency
# *   Tree of Thought
# *   Group of Thought

# %%
# !pip -q install transformers accelerate sentencepiece

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# %%
MODEL_NAME = "Qwen/Qwen2.5-0.5B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    torch_dtype="auto",
    device_map="auto"
)
# Out:
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]

# %%
def ask_llm(prompt):

    messages = [
        {
            "role": "user",
            "content": prompt
        }
    ]

    text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = tokenizer(text, return_tensors="pt").to(model.device)

    outputs = model.generate(
        **inputs,
        max_new_tokens=250,
        do_sample=False
    )

    answer = tokenizer.decode(
        outputs[0][inputs.input_ids.shape[1]:],
        skip_special_tokens=True
    )

    return answer.strip()

# %%
problem = """
If the train moves 60 kilometer per hour

for 2 hours,

How far will it go?

"""

print(problem)
# Out:
# If the train moves 60 kilometer per hour
#
# for 2 hours,
#
# How far will it go?

# %% [markdown]
# **1 Baseline Prompt**

# %%
print("="*60)
print("BASELINE PROMPT")
print("="*60)

prompt = problem

print(ask_llm(prompt))
# Out:
# ============================================================
# BASELINE PROMPT
# ============================================================
# To determine how far the train will travel in 2 hours at a speed of 60 kilometers per hour, you can use the formula for distance:
#
# \[ \text{Distance} = \text{Speed} \times \text{Time} \]
#
# Given:
# - Speed = 60 kilometers per hour
# - Time = 2 hours
#
# Substitute the given values into the formula:
#
# \[ \text{Distance} = 60 \, \text{kilometers/hour} \times 2 \, \text{hours} \]
# \[ \text{Distance} = 120 \, \text{kilometers} \]
#
# So, the train will travel 120 kilometers in 2 hours.

# %% [markdown]
# **No Explaination**

# %%
print("="*60)
print("BASELINE PROMPT")
print("="*60)

prompt = f"""
Answer only.

{problem}
"""

print(ask_llm(prompt))
# Out:
# ============================================================
# BASELINE PROMPT
# ============================================================
# The distance traveled is calculated as follows:
#
# \[ \text{Distance} = \text{Speed} \times \text{Time} \]
#
# Given:
# - Speed = 60 km/hour
# - Time = 2 hours
#
# So,
# \[ \text{Distance} = 60 \, \text{km/hour} \times 2 \, \text{hours} = 120 \, \text{km} \]
#
# Therefore, the train will travel a total distance of 120 kilometers.

# %% [markdown]
# **2 Zero-Shot Prompting**

# %%
print("="*60)
print("ZERO SHOT PROMPTING")
print("="*60)

prompt = f"""
You are an expert mathematician.

Solve the following question.

Question

{problem}

Answer
"""

print(ask_llm(prompt))
# Out:
# ============================================================
# ZERO SHOT PROMPTING
# ============================================================
# To solve this problem, we need to use the formula for distance traveled:
#
# \[ \text{Distance} = \text{Speed} \times \text{Time} \]
#
# Given:
# - Speed of the train = 60 kilometers per hour
# - Time taken = 2 hours
#
# We can substitute these values into the formula:
#
# \[ \text{Distance} = 60 \, \text{kilometers/hour} \times 2 \, \text{hours} \]
#
# Let's calculate the distance:
#
# \[ \text{Distance} = 120 \, \text{kilometers} \]
#
# So, the train will travel 120 kilometers in 2 hours.

# %% [markdown]
# **3 Better Zero Shot**

# %%
print("="*60)
print("ZERO SHOT (STRICT)")
print("="*60)

prompt = f"""
You are an expert math solver.

Read carefully.

Return ONLY the final answer.

Question

{problem}

Final Answer
"""

print(ask_llm(prompt))
# Out:
# ============================================================
# ZERO SHOT (STRICT)
# ============================================================
# 120 kilometers

# %% [markdown]
# **4 Few Shot Prompting**

# %%
print("="*60)
print("FEW SHOT")
print("="*60)

prompt = """
Question:
Ali has 2 apples and 3 oranges.

How many fruits he have in basket?

Answer:
5

Question:
Sara has 10 chocolates.

She eats 4.

Answer:
6

Question:

If the train moves 60 kilometer per hour

for 2 hours,

How far will it go?
Answer:
"""

print(ask_llm(prompt))
# Out:
# ============================================================
# FEW SHOT
# ============================================================
# The answer is 120 kilometers.

# %% [markdown]
# **5 Chain of Thought**

# %%
print("="*60)
print("CHAIN OF THOUGHT")
print("="*60)

prompt = f"""
Solve the problem.

Think step by step.

Question

{problem}

Answer
"""

print(ask_llm(prompt))
# Out:
# ============================================================
# CHAIN OF THOUGHT
# ============================================================
# To solve this problem, we need to calculate the distance traveled by the train based on its speed and time. The formula for distance is:
#
# \[ \text{Distance} = \text{Speed} \times \text{Time} \]
#
# Given:
# - Speed of the train = 60 kilometers per hour
# - Time taken = 2 hours
#
# Step-by-step solution:
#
# 1. Identify the given values:
#    - Speed (s) = 60 km/hour
#    - Time (t) = 2 hours
#
# 2. Use the formula for distance:
#    \[ \text{Distance} = s \times t \]
#    where \( s \) is the speed in kilometers per hour and \( t \) is the time in hours.
#
# 3. Substitute the given values into the formula:
#    \[ \text{Distance} = 60 \, \text{km/hour} \times 2 \, \text{hours} \]
#
# 4. Perform the multiplication:
#    \[ \text{Distance} = 120 \, \text{km} \]
#
# Therefore, the train will travel a distance of **120 kilometers**.

# %% [markdown]
# **6 Zero-Shot CoT**
#
# This is the famous paper prompt.
#
# Only one sentence changes.

# %%
print("="*60)
print("ZERO SHOT CoT")
print("="*60)

prompt = f"""
{problem}

Let's think step by step.
"""

print(ask_llm(prompt))
# Out:
# ============================================================
# ZERO SHOT CoT
# ============================================================
# To determine how far the train will travel given its speed and time, we can use the formula for distance:
#
# \[ \text{Distance} = \text{Speed} \times \text{Time} \]
#
# Here, the speed of the train is 60 kilometers per hour (km/h), and the time it travels is 2 hours.
#
# Step-by-step calculation:
#
# 1. Identify the speed: \( \text{Speed} = 60 \) km/h.
# 2. Identify the time: \( \text{Time} = 2 \) hours.
# 3. Multiply the speed by the time to find the distance:
#
# \[
# \text{Distance} = 60 \, \text{km/h} \times 2 \, \text{hours}
# \]
#
# 4. Perform the multiplication:
#
# \[
# \text{Distance} = 120 \, \text{km}
# \]
#
# Therefore, the train will travel a total distance of 120 kilometers.

# %% [markdown]
# **7 Self Consistency**

# %%
def ask_sample(prompt):

    messages = [
        {
            "role":"user",
            "content":prompt
        }
    ]

    text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = tokenizer(text, return_tensors="pt").to(model.device)

    outputs = model.generate(
        **inputs,
        max_new_tokens=200,
        do_sample=True,
        temperature=0.8,
        top_p=0.9
    )

    return tokenizer.decode(
        outputs[0][inputs.input_ids.shape[1]:],
        skip_special_tokens=True
    )

# %%
prompt = f"""
{problem}

Let's think step by step.

At the end, write your answer in exactly this format:

Final Answer: <answer>
"""

for i in range(5):

    print("="*50)
    print("Reasoning Path", i+1)
    print("="*50)

    print(ask_sample(prompt))
# Out:
# ==================================================
# Reasoning Path 1
# ==================================================
# To calculate how far the train will travel given its speed and duration, we can use the formula for distance traveled at constant speed:
#
# \[
# \text{Distance} = \text{Speed} \times \text{Time}
# \]
#
# Given:
# - Speed = 60 kilometers per hour (km/h)
# - Time = 2 hours
#
# Plugging these values into the formula:
#
# \[
# \text{Distance} = 60 \, \text{km/h} \times 2 \, \text{hours} = 120 \, \text{kilometers}
# \]
#
# Therefore, the final answer is:
#
# \[
# \boxed{120 \, \text{kilometers}}
# \]
# ==================================================
# Reasoning Path 2
# ==================================================
# Final Answer: 120 kilometers
#
# Step-by-step explanation:
# 1. We know that the train moves at a speed of 60 kilometers per hour.
# 2. The question states that it travels for 2 hours.
# 3. To calculate the distance traveled, we use the formula: Distance = Speed × Time.
# 4. Substituting the given values into the formula gives us: Distance = 60 km/h × 2 h = 120 km.
# 5. Therefore, the final answer is 120 kilometers.
# ==================================================
# Reasoning Path 3
# ==================================================
# To determine how far the train travels at a speed of 60 kilometers per hour for 2 hours, we can use the formula for distance:
#
# \[ \text{Distance} = \text{Speed} \times \text{Time} \]
#
# Here, the speed is 60 kilometers per hour and the time is 2 hours. Plugging these values into the formula gives us:
#
# \[ \text{Distance} = 60 \, \text{km/h} \times 2 \, \text{h} \]
# \[ \text{Distance} = 120 \, \text{km} \]
#
# So, the final answer is:
#
# \[ \boxed{120 \, \text{km}} \]
# ==================================================
# Reasoning Path 4
# ==================================================
# To determine how far the train will travel given its speed and time, you can use the formula for distance traveled:
#
# \[ \text{Distance} = \text{Speed} \times \text{Time} \]
#
# Given:
# - Speed of the train = 60 kilometers per hour
# - Time taken to travel = 2 hours
#
# Now, plug these values into the formula:
#
# \[ \text{Distance} = 60 \, \text{kilometers/hour} \times 2 \, \text{hours} \]
# \[ \text{Distance} = 120 \, \text{kilometers} \]
#
# So, if the train moves at a speed of 60 kilometers per hour for 2 hours, it will cover a total distance of **120 kilometers**.
# ==================================================
# Reasoning Path 5
# ==================================================
# To determine how far the train will travel given its speed and time, we can use the formula for distance traveled at constant speed:
#
# \[ \text{Distance} = \text{Speed} \times \text{Time} \]
#
# Given:
# - Speed of the train = 60 kilometers per hour
# - Time taken = 2 hours
#
# Now, plug these values into the formula:
#
# \[ \text{Distance} = 60 \, \text{kilometers/hour} \times 2 \, \text{hours} \]
# \[ \text{Distance} = 120 \, \text{kilometers} \]
#
# Therefore, if the train moves at 60 kilometers per hour for 2 hours, it will cover **120 kilometers**.

# %%
from collections import Counter

answers = []

for i in range(5):

    print("="*50)
    print("Reasoning Path", i+1)
    print("="*50)

    response = ask_sample(prompt)
    print(response)

    answers.append(response)
# Out:
# ==================================================
# Reasoning Path 1
# ==================================================
# The distance traveled by the train can be calculated using the formula:
#
# \[ \text{Distance} = \text{Speed} \times \text{Time} \]
#
# Given:
# - Speed = 60 km/hour
# - Time = 2 hours
#
# So, substituting these values into the formula gives us:
#
# \[ \text{Distance} = 60 \, \text{km/h} \times 2 \, \text{hours} \]
# \[ \text{Distance} = 120 \, \text{km} \]
#
# Therefore, the final answer is: The train will travel **120 kilometers**.
# ==================================================
# Reasoning Path 2
# ==================================================
# Final Answer: 120 kilometers
#
# Explanation:
# The train has been moving for 2 hours at a speed of 60 kilometers per hour.
# To find out how far the train travels in 2 hours, we use the formula:
# Distance = Speed × Time
#
# So, distance = 60 km/h × 2 h = 120 km
#
# Thus, the train will have traveled 120 kilometers.
# ==================================================
# Reasoning Path 3
# ==================================================
# To calculate the distance covered by the train, we can use the formula for distance, which is:
#
# \[ \text{Distance} = \text{Speed} \times \text{Time} \]
#
# Given:
# - Speed = 60 km/hour
# - Time = 2 hours
#
# Now, let's plug these values into the formula:
#
# \[ \text{Distance} = 60 \, \text{km/h} \times 2 \, \text{hours} \]
# \[ \text{Distance} = 120 \, \text{km} \]
#
# So, the train will cover a distance of **120 kilometers** after moving at 60 kilometers per hour for 2 hours.
# ==================================================
# Reasoning Path 4
# ==================================================
# Final Answer: 120 kilometers
#
# Explanation:
# The train is initially moving at 60 kilometers per hour for 2 hours. To find out how far the train travels during this time, we can use the formula:
#
# \[ \text{Distance} = \text{Speed} \times \text{Time} \]
#
# Given that the speed of the train is 60 km/h and the time taken to travel is 2 hours, we can calculate the distance as follows:
#
# \[ \text{Distance} = 60 \, \text{km/h} \times 2 \, \text{h} = 120 \, \text{km} \]
#
# So, the train will have traveled a distance of 120 kilometers after 2 hours.
# ==================================================
# Reasoning Path 5
# ==================================================
# Final Answer: 120 kilometers
# Explanation:
# - The train is moving at a speed of 60 kilometers per hour.
# - It travels for 2 hours.
# - To find out how far the train covers, we multiply the speed by the time:
#   \[
#   \text{Distance} = \text{Speed} \times \text{Time}
#   \]
#   Substituting the given values:
#   \[
#   \text{Distance} = 60 \, \text{kilometers/hour} \times 2 \, \text{hours} = 120 \, \text{kilometers}
#   \]
#
# Therefore, the train will cover a distance of 120 kilometers in 2 hours.

# %%
import re
from collections import Counter

print("\n" + "="*60)
print("FINAL ANSWERS FROM EACH PATH")
print("="*60)

final_answers = []

for i, response in enumerate(answers, 1):

    # Look for "Final Answer: ..."
    match = re.search(
        r"Final\s*Answer\s*:\s*(.+)",
        response,
        flags=re.IGNORECASE
    )

    if match:
        answer = match.group(1).strip()

    else:
        # Fallback: extract the last number if the expected format is missing
        numbers = re.findall(r"\d+(?:\.\d+)?", response)

        if numbers:
            answer = numbers[-1]
        else:
            answer = "Unknown"

    final_answers.append(answer)

    print(f"Path {i}: {answer}")

# ----------------------------
# Majority Voting
# ----------------------------

vote = Counter(final_answers)

most_common_answer, votes = vote.most_common(1)[0]

print("\n" + "="*60)
print("MAJORITY VOTING")
print("="*60)

for ans, count in vote.items():
    print(f"{ans} : {count} vote(s)")

print("\n" + "-"*60)
print(f"Final Selected Answer : {most_common_answer}")
print(f"Majority Votes        : {votes}/{len(final_answers)}")
print("-"*60)
# Out:
# ============================================================
# FINAL ANSWERS FROM EACH PATH
# ============================================================
# Path 1: 120
# Path 2: 120 kilometers
# Path 3: 2
# Path 4: 120 kilometers
# Path 5: 120 kilometers
#
# ============================================================
# MAJORITY VOTING
# ============================================================
# 120 : 1 vote(s)
# 120 kilometers : 3 vote(s)
# 2 : 1 vote(s)
#
# ------------------------------------------------------------
# Final Selected Answer : 120 kilometers
# Majority Votes        : 3/5
# ------------------------------------------------------------

# %%
import re
from collections import Counter

print("\n" + "="*60)
print("FINAL ANSWERS FROM EACH PATH")
print("="*60)

final_answers = []

for i, response in enumerate(answers, 1):

    # ----------------------------------------
    # First try to extract "Final Answer:"
    # ----------------------------------------
    match = re.search(
        r"Final\s*Answer\s*:\s*(.+)",
        response,
        flags=re.IGNORECASE
    )

    if match:
        raw_answer = match.group(1).strip()

        # Extract the FIRST number after "Final Answer:"
        num = re.search(r"\d+(?:\.\d+)?", raw_answer)

        if num:
            answer = num.group(0)
        else:
            answer = raw_answer

    else:
        # ----------------------------------------
        # Fallback:
        # No "Final Answer:" found.
        # Take the LAST number from the entire response.
        # ----------------------------------------
        numbers = re.findall(r"\d+(?:\.\d+)?", response)

        if numbers:
            answer = numbers[-1]
        else:
            answer = "Unknown"

    final_answers.append(answer)

    print(f"Path {i}: {answer}")

# ----------------------------------------
# Majority Voting
# ----------------------------------------

vote = Counter(final_answers)

most_common_answer, votes = vote.most_common(1)[0]

print("\n" + "="*60)
print("MAJORITY VOTING")
print("="*60)

for ans, count in vote.items():
    print(f"{ans} : {count} vote(s)")

print("\n" + "-"*60)
print(f"Final Selected Answer : {most_common_answer}")
print(f"Majority Votes        : {votes}/{len(final_answers)}")
print("-"*60)
# Out:
# ============================================================
# FINAL ANSWERS FROM EACH PATH
# ============================================================
# Path 1: 120
# Path 2: 120
# Path 3: 2
# Path 4: 120
# Path 5: 120
#
# ============================================================
# MAJORITY VOTING
# ============================================================
# 120 : 4 vote(s)
# 2 : 1 vote(s)
#
# ------------------------------------------------------------
# Final Selected Answer : 120
# Majority Votes        : 4/5
# ------------------------------------------------------------

# %% [markdown]
# **Tree of Thoughts (ToT)**

# %%
def generate_thought(problem):

    prompt = f"""
You are solving a reasoning problem using the Tree of Thoughts (ToT) approach.

Your task is to generate ONE possible reasoning path.

Instructions:
- Think step by step.
- Explore one possible solution.
- Do not assume this is the only correct reasoning.
- This reasoning will later be compared with other candidate thoughts.
- End with:

Final Answer: <your answer>

Problem:
{problem}
"""

    return ask_llm(prompt)

# %%
def generate_multiple_thoughts(problem, n=3):

    thoughts = []

    for i in range(n):

        prompt = f"""
You are solving a reasoning problem using the Tree of Thoughts (ToT) approach.

Generate ONE independent reasoning path.

Instructions:
- Think step by step.
- Explore a possible solution.
- This is only ONE candidate thought.
- Different reasoning paths will be generated and compared later.
- Focus on logical and consistent reasoning.
- End with:

Final Answer: <your answer>

Problem:
{problem}
"""

        messages = [
            {
                "role": "user",
                "content": prompt
            }
        ]

        text = tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=True
        )

        inputs = tokenizer(text, return_tensors="pt").to(model.device)

        outputs = model.generate(
            **inputs,
            do_sample=True,
            temperature=0.9,
            top_p=0.9,
            max_new_tokens=250
        )

        answer = tokenizer.decode(
            outputs[0][inputs.input_ids.shape[1]:],
            skip_special_tokens=True
        )

        thoughts.append(answer)

    return thoughts

# %%
thoughts = generate_multiple_thoughts(problem, n=3)

print("=" * 80)
print("TREE OF THOUGHTS : GENERATED CANDIDATE REASONING PATHS")
print("=" * 80)

for i, thought in enumerate(thoughts, start=1):

    print(f"\n{'=' * 80}")
    print(f"THOUGHT PATH {i}")
    print(f"{'=' * 80}")

    print(thought)
# Out:
# ================================================================================
# TREE OF THOUGHTS : GENERATED CANDIDATE REASONING PATHS
# ================================================================================
#
# ================================================================================
# THOUGHT PATH 1
# ================================================================================
# 1. **Understand the Problem:**
#    The train's speed is given as 60 kilometers per hour for 2 hours.
#
# 2. **Calculate Distance:**
#    To find out how far the train travels, we can use the formula for distance in one-dimensional motion:
#    \[
#    \text{Distance} = \text{Speed} \times \text{Time}
#    \]
#    Here, the speed is 60 km/h and the time is 2 hours.
#    \[
#    \text{Distance} = 60 \text{ km/h} \times 2 \text{ h} = 120 \text{ km}
#    \]
#
# 3. **Conclusion:**
#    Therefore, the train will travel a distance of 120 kilometers.
#
# 4. **Final Answer:**
#    \boxed{120 \text{ km}}
#
# ================================================================================
# THOUGHT PATH 2
# ================================================================================
# 1. **Identify Given Information**:
#    - Train speed: 60 km/hour
#    - Time traveled: 2 hours
#
# 2. **Determine Speed in Terms of Distance**:
#    - Speed = Distance / Time
#
# 3. **Calculate Distance Traveled**:
#    - Distance = Speed × Time
#
# 4. **Substitute the Values**:
#    - Distance = 60 km/hour × 2 hours
#
# 5. **Perform Calculation**:
#    - Distance = 120 kilometers
#
# Therefore, if the train moves at a speed of 60 km/h for 2 hours, it will travel **120 kilometers**.
#
# ================================================================================
# THOUGHT PATH 3
# ================================================================================
# Step-by-step analysis:
# 1. The train's speed is given as 60 kilometers per hour.
# 2. It travels for 2 hours.
# 3. We need to calculate the distance traveled using the formula Distance = Speed × Time.
# 4. Plug in the values into the formula:
#    Distance = 60 km/h × 2 h = 120 km.
#
# Therefore, the train will travel 120 kilometers if it moves at 60 kilometers per hour for 2 hours.

# %% [markdown]
# **Graph of Thoughts (GoT)**

# %%
def initial_thoughts(problem):

    prompt = f"""
You are working in a Group of Thoughts (GoT) reasoning framework.

Your task is to generate EXACTLY TWO different high-level solution ideas.

IMPORTANT RULES:
- Do NOT solve the problem.
- Do NOT calculate the final answer.
- Do NOT provide step-by-step reasoning.
- Each idea should describe only a possible approach.
- The two ideas should use different reasoning strategies.

Problem:
{problem}

Return ONLY in the following format:

Idea 1:
<one or two sentences describing the first approach>

Idea 2:
<one or two sentences describing the second approach>
"""

    return ask_llm(prompt)

# %%
def expand_idea(problem, idea):

    prompt = f"""
You are working in a Group of Thoughts (GoT) reasoning framework.

Expand the given solution idea into a detailed reasoning path.

IMPORTANT RULES:
- Expand ONLY the given idea.
- Do NOT introduce a completely new approach.
- Keep the reasoning consistent with the original idea.
- Explain the reasoning step by step.
- Do NOT provide the final answer.
- Do NOT conclude the problem.

Problem:
{problem}

Solution Idea:
{idea}

Return ONLY in the following format:

Expanded Reasoning:
<step-by-step reasoning based only on the given idea>
"""

    return ask_llm(prompt)

# %%
def merge_ideas(problem, idea1, idea2):

    prompt = f"""
You are working in a Group of Thoughts (GoT) reasoning framework.

Your task is to combine the two reasoning paths into ONE stronger reasoning path.

IMPORTANT RULES:
- Do NOT choose one idea and ignore the other.
- Identify the strengths of BOTH reasoning paths.
- Merge their useful information into one coherent reasoning.
- Remove any redundant or contradictory statements.
- Preserve the logical flow.
- Do NOT generate a completely new approach.
- Do NOT provide the final answer yet.

Problem:
{problem}

Expanded Reasoning 1:
{idea1}

Expanded Reasoning 2:
{idea2}

Return ONLY in the following format:

Merged Reasoning:
<one improved reasoning path that combines both ideas>
"""

    return ask_llm(prompt)

# %%
def final_answer(problem, merged):

    prompt = f"""
You are working in a Group of Thoughts (GoT) reasoning framework.

The reasoning from multiple solution ideas has already been generated,
expanded, and merged into one improved reasoning path.

Your task is to:

1. Use ONLY the merged reasoning below.
2. Solve the problem using that reasoning.
3. Do NOT generate a new approach.
4. Do NOT ignore the merged reasoning.
5. Clearly explain the final reasoning.
6. Provide the final answer.

Problem:
{problem}

Merged Reasoning:
{merged}

Return ONLY in the following format:

Final Reasoning:
<brief reasoning based on the merged reasoning>

Final Answer:
<answer only>
"""

    return ask_llm(prompt)

# %%
ideas = initial_thoughts(problem)

print("\n" + "=" * 80)
print("GROUP OF THOUGHTS (GoT) : INITIAL IDEA GENERATION")
print("=" * 80)

print("\nThe model generated multiple high-level solution ideas.")
print("These are NOT complete solutions.")
print("They represent different approaches that will be expanded and merged later.\n")

print("=" * 80)
print("GENERATED INITIAL IDEAS")
print("=" * 80)

print(ideas)

print("\n" + "=" * 80)
print("NEXT STEP")
print("=" * 80)

print("Each idea will now be expanded into a detailed reasoning path.")
# Out:
# ================================================================================
# GROUP OF THOUGHTS (GoT) : INITIAL IDEA GENERATION
# ================================================================================
#
# The model generated multiple high-level solution ideas.
# These are NOT complete solutions.
# They represent different approaches that will be expanded and merged later.
#
# ================================================================================
# GENERATED INITIAL IDEAS
# ================================================================================
# Idea 1:
# Calculate distance using formula: Distance = Speed × Time
#
# Idea 2:
# Use proportionality between speed and time to find distance directly from given information.
#
# Both approaches utilize basic mathematical principles but differ in their specific application. Idea 1 involves direct calculation based on the provided data, while Idea 2 leverages a proportional relationship to derive the unknown quantity.
#
# ================================================================================
# NEXT STEP
# ================================================================================
# Each idea will now be expanded into a detailed reasoning path.

# %%
import re


match1 = re.search(r"Idea\s*1\s*:\s*(.+?)(?=Idea\s*2\s*:|$)", ideas, flags=re.IGNORECASE | re.DOTALL)
match2 = re.search(r"Idea\s*2\s*:\s*(.+)", ideas, flags=re.IGNORECASE | re.DOTALL)

idea1 = match1.group(1).strip() if match1 else ""
idea2 = match2.group(1).strip() if match2 else ""

print("=" * 80)
print("PARSED IDEAS")
print("=" * 80)
print(f"Idea 1: {idea1}\n")
print(f"Idea 2: {idea2}")

expanded1 = expand_idea(problem, idea1)
expanded2 = expand_idea(problem, idea2)

print("\n" + "=" * 80)
print("EXPANDED REASONING 1")
print("=" * 80)
print(expanded1)

print("\n" + "=" * 80)
print("EXPANDED REASONING 2")
print("=" * 80)
print(expanded2)

merged = merge_ideas(problem, expanded1, expanded2)

print("\n" + "=" * 80)
print("MERGED REASONING")
print("=" * 80)
print(merged)

result = final_answer(problem, merged)

print("\n" + "=" * 80)
print("GROUP OF THOUGHTS : FINAL RESULT")
print("=" * 80)
print(result)
# Out:
# ================================================================================
# PARSED IDEAS
# ================================================================================
# Idea 1: Calculate distance using formula: Distance = Speed × Time
#
# Idea 2: Use proportionality between speed and time to find distance directly from given information.
#
# Both approaches utilize basic mathematical principles but differ in their specific application. Idea 1 involves direct calculation based on the provided data, while Idea 2 leverages a proportional relationship to derive the unknown quantity.
#
# ================================================================================
# EXPANDED REASONING 1
# ================================================================================
# Expanded Reasoning:
# To calculate how far the train will travel, we can use the formula for distance, which is:
#
# \[ \text{Distance} = \text{Speed} \times \text{Time} \]
#
# Given that the speed of the train is 60 kilometers per hour and it travels for 2 hours, we can substitute these values into the formula:
#
# \[ \text{Distance} = 60 \, \text{kilometers/hour} \times 2 \, \text{hours} \]
#
# Now, let's perform the multiplication to find the total distance traveled by the train.
#
# \[ \text{Distance} = 120 \, \text{kilometers} \]
#
# Therefore, the train will have traveled 120 kilometers when it has been moving for 2 hours at a speed of 60 kilometers per hour.
#
# ================================================================================
# EXPANDED REASONING 2
# ================================================================================
# Expanded Reasoning:
# To determine how far the train will travel, we can use the concept of direct proportionality between speed and time. This means that if the speed is constant, the distance traveled will be directly proportional to the time taken.
#
# Given:
# - Speed = 60 km/hour
# - Time = 2 hours
#
# We need to find the distance \( d \).
#
# Step 1: Set up the proportionality equation using the given values.
# \[ \frac{\text{Speed}}{\text{Time}} = \frac{\text{Distance}}{\text{Time}} \]
#
# Step 2: Substitute the known values into the equation.
# \[ \frac{60}{2} = \frac{d}{2} \]
#
# Step 3: Solve for \( d \).
# \[ d = 60 \times 2 \]
# \[ d = 120 \]
#
# Therefore, the train will travel 120 kilometers.
#
# ================================================================================
# MERGED REASONING
# ================================================================================
# Merged Reasoning:
# The train will travel a distance equal to its speed multiplied by the time it travels, assuming the speed remains constant. Given the speed is 60 km/hour and the time is 2 hours, the calculation yields a distance of 120 kilometers.
#
# ================================================================================
# GROUP OF THOUGHTS : FINAL RESULT
# ================================================================================
# **Final Reasoning:**
# The train will travel a distance equal to its speed multiplied by the time it travels, assuming the speed remains constant. Given the speed is 60 km/hour and the time is 2 hours, the calculation yields a distance of 120 kilometers.
#
# **Final Answer:**
# 120 kilometers
